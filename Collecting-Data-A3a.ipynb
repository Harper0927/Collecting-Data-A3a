# %%
import pandas as pd

# %%
pd.options.display.max_rows = 200

# %%
motor_df = pd.read_csv('2014_Nacionalitat_propietaris_motos-1.csv', delimiter=",", encoding='utf-8')

# %%
motor_df.sample(10)
# Out:
#       Any  Codi_Districte   Nom_Districte  Codi_Barri  \
# 44   2014               8      Nou Barris          45
# 36   2014               7  Horta-Guinardó          37
# 92   2014               4       Les Corts          19
# 76   2014               1    Ciutat Vella           3
# 136  2014               9     Sant Andreu          63
# 17   2014               3  Sants-Montjuïc          18
# 57   2014               9     Sant Andreu          58
# 1    2014               1    Ciutat Vella           2
# 119  2014               8      Nou Barris          46
# 43   2014               8      Nou Barris          44
#
#                          Nom_Barri Nacionalitat_propietari  Nombre_motos
# 44                           Porta               Espanyola          1804
# 36                       el Carmel               Espanyola          3593
# 92                       les Corts              Estrangera           319
# 76                  la Barceloneta              Estrangera           273
# ...

# %%
motor_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Any                      148 non-null    int64
#  1   Codi_Districte           148 non-null    int64
#  2   Nom_Districte            148 non-null    object
#  3   Codi_Barri               148 non-null    int64
#  4   Nom_Barri                148 non-null    object
#  5   Nacionalitat_propietari  148 non-null    object
#  6   Nombre_motos             148 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 8.2+ KB

# %%
motor_df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'Any'}>,
#         <Axes: title={'center': 'Codi_Districte'}>],
#        [<Axes: title={'center': 'Codi_Barri'}>,
#         <Axes: title={'center': 'Nombre_motos'}>]], dtype=object)

# %%
motor_df.describe(include='all')
# Out:
#            Any  Codi_Districte Nom_Districte  Codi_Barri Nom_Barri  \
# count    148.0      148.000000           148  148.000000       148
# unique     NaN             NaN            11         NaN        74
# top        NaN             NaN    Nou Barris         NaN  el Raval
# freq       NaN             NaN            26         NaN         2
# mean    2014.0        7.500000           NaN   37.837838       NaN
# std        0.0       11.099121           NaN   22.193967       NaN
# min     2014.0        1.000000           NaN    1.000000       NaN
# 25%     2014.0        4.000000           NaN   19.000000       NaN
# 50%     2014.0        7.000000           NaN   37.500000       NaN
# 75%     2014.0        8.000000           NaN   56.000000       NaN
# max     2014.0       99.000000           NaN   99.000000       NaN
#
#        Nacionalitat_propietari  Nombre_motos
# count                      148    148.000000
# unique                       2           NaN
# ...

# %%
motor_df = motor_df.drop(motor_df[motor_df['Nombre_motos'] < 1000].index)

# %%
motor_df
# Out:
#      Any  Codi_Districte        Nom_Districte  Codi_Barri  \
# 0   2014               1         Ciutat Vella           1
# 1   2014               1         Ciutat Vella           2
# 2   2014               1         Ciutat Vella           3
# 3   2014               1         Ciutat Vella           4
# 4   2014               2             Eixample           5
# 5   2014               2             Eixample           6
# 6   2014               2             Eixample           7
# 7   2014               2             Eixample           8
# 8   2014               2             Eixample           9
# 9   2014               2             Eixample          10
# 10  2014               3       Sants-Montjuïc          11
# 12  2014               3       Sants-Montjuïc          13
# 13  2014               3       Sants-Montjuïc          14
# 14  2014               3       Sants-Montjuïc          15
# 15  2014               3       Sants-Montjuïc          16
# ...

# %%
motor_df.sort_values(by='Nombre_motos', ascending=False).head(20)
# Out:
#      Any  Codi_Districte        Nom_Districte  Codi_Barri  \
# 25  2014               5  Sarrià-Sant Gervasi          26
# 8   2014               2             Eixample           9
# 6   2014               2             Eixample           7
# 18  2014               4            Les Corts          19
# 7   2014               2             Eixample           8
# 30  2014               6               Gràcia          31
# 24  2014               5  Sarrià-Sant Gervasi          25
# 26  2014               5  Sarrià-Sant Gervasi          27
# 5   2014               2             Eixample           6
# 22  2014               5  Sarrià-Sant Gervasi          23
# 59  2014               9          Sant Andreu          60
# 31  2014               6               Gràcia          32
# 17  2014               3       Sants-Montjuïc          18
# 23  2014               5  Sarrià-Sant Gervasi          24
# 34  2014               7       Horta-Guinardó          35
# ...

# %%
motor_df.groupby(by=['Codi_Districte', 'Nom_Districte'])['Nombre_motos'].sum()
# Out:
# Codi_Districte  Nom_Districte
# 1               Ciutat Vella            9739
# 2               Eixample               34713
# 3               Sants-Montjuïc         17254
# 4               Les Corts              13726
# 5               Sarrià-Sant Gervasi    34339
# 6               Gràcia                 16841
# 7               Horta-Guinardó         18434
# 8               Nou Barris              9451
# 9               Sant Andreu            11448
# 10              Sant Martí             20716
# Name: Nombre_motos, dtype: int64

# %%
District_num=motor_df.groupby(by=['Codi_Districte', 'Nom_Districte'])['Nombre_motos'].sum()

# %%
District_num.plot(kind='bar')
# Out:
# <Axes: xlabel='Codi_Districte,Nom_Districte'>
